# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import  ords_prods_merge dataframe
path_ords_prods_merge = r'/Users/janekobtseva/19-09-2024 Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge.pkl'

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path_ords_prods_merge))

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   3139998      138    prior            28          6
# 1             19     5.8   1977647      138    prior            30          6
# 2             19     5.8    389851      709    prior             2          0
# 3             19     5.8    652770      764    prior             1          3
# 4             19     5.8   1813452      764    prior             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merge.describe()
# Out:
#          Unnamed: 0    product_id      aisle_id  department_id        prices  \
# count  3.240604e+07  3.240604e+07  3.240604e+07   3.240604e+07  3.240604e+07
# mean   2.560065e+04  2.559895e+04  7.119773e+01   9.919923e+00  1.198004e+01
# std    1.408544e+04  1.408389e+04  3.821182e+01   6.281418e+00  4.956464e+02
# min    0.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# 25%    1.354400e+04  1.354400e+04  3.100000e+01   4.000000e+00  4.200000e+00
# 50%    2.530600e+04  2.530500e+04  8.300000e+01   9.000000e+00  7.400000e+00
# 75%    3.795100e+04  3.794700e+04  1.070000e+02   1.600000e+01  1.130000e+01
# max    4.969200e+04  4.968800e+04  1.340000e+02   2.100000e+01  9.999900e+04
#
#            order_id       user_id  order_number     order_dow  \
# count  3.240604e+07  3.240604e+07  3.240604e+07  3.240604e+07
# mean   1.710745e+06  1.029371e+05  1.714223e+01  2.738862e+00
# std    9.872986e+05  5.946610e+04  1.753527e+01  2.090074e+00
# ...

# %%
#create a subset
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %%
#define a function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#apply the function


df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_1414/3283472641.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product    652593
# Low-range product    338063
# High range             9344
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     21861997
# Low-range product     10126366
# High-range product      417678
# Name: count, dtype: int64

# %%
#If-Statements with For-Loops

result = []

for value in df_ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge ["Busiest day"] = result

# %%
df_ords_prods_merge ["Busiest day"].value_counts(dropna=False)
# Out:
# Busiest day
# Regularly busy    22417684
# Busiest day        6204404
# Least busy         3783953
# Name: count, dtype: int64

# %%
#Task4.7
#“Busiest day” to become “Busiest days” (plural). + two slowest days.

# %%
#I tried to do with if, but it gives me the same arror. thus I have used Loc
def busiest_day_2(row):

  if (row['order_dow'] <= 1):
    return 'Busiest days'
  elif (row['order_dow'] >= 5):
    return 'Slowest days'
  else: return 'Average_orders'

# %%
df['busiest_day_2'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_1414/1392534582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['busiest_day_2'] = df.apply(price_label, axis=1)

# %%
#Please have a look at loc here. So we can see 2 busiest days as well as 2 slowest days. And all days btween them, as average 

df_ords_prods_merge.loc[(df_ords_prods_merge['order_dow'] <= 1), 'ords_prods_merge_order_dow.loc'] = 'Busiest days'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_dow'] >= 5), 'ords_prods_merge_order_dow.loc'] = 'Slowest days'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_dow'] < 5)&(df_ords_prods_merge['order_dow'] > 1), 'ords_prods_merge_order_dow.loc'] = 'Average days'

# %%
df_ords_prods_merge['ords_prods_merge_order_dow.loc'].value_counts(dropna=False)
# Out:
# ords_prods_merge_order_dow.loc
# Busiest days    11864860
# Average days    11838640
# Slowest days     8702541
# Name: count, dtype: int64

# %%
# identify the busiest hours of the day. 
#periods of time labeled 
#“Most orders,” “Average orders,” and “Fewest orders.” column - “busiest_period_of_day.
df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] < 10) , 'busiest_period_of_day'] = 'Fewest_orders'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] >= 12)& (df_ords_prods_merge['order_hour_of_day'] <= 14), 'busiest_period_of_day'] = 'Most_orders'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] > 10)& (df_ords_prods_merge['order_hour_of_day'] < 12), 'busiest_period_of_day'] = 'Average_orders'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] > 14)& (df_ords_prods_merge['order_hour_of_day'] < 16), 'busiest_period_of_day'] = 'Average_orders'

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# NaN               13088236
# Most_orders        7968921
# Fewest_orders      5950396
# Average_orders     5398488
# Name: count, dtype: int64

# %%
#If we will look at the periods to see number of orders per hour of busiest_period_of_day
#we will get the following 
#Fewest_orders 19 038 632 - 1.119.919 orders p/h
#Most_orders 7 968 921 - 3 984.460 orders p/h
#Average_orders 5 398 488 - 1.349.622 orders p/h

#I believe the logic is correct

# %%
#Export file in pickle format as ords_prods_merge_new_variable.pkl

path_prepared_data = r'/Users/janekobtseva/19-09-2024 Instacart Basket Analysis/02 Data/Prepared Data'

# %%
df_ords_prods_merge.to_pickle(os.path.join(path_prepared_data, 'ords_prods_merge_new_variable.pkl'))
