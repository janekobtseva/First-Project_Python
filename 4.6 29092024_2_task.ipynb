# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import  orders_products_combined dataframe
path_orders_products_combined = r'/Users/janekobtseva/19-09-2024 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl'

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path_orders_products_combined))

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#Check the shape of the imported dataframe
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
# Import  df_prods_clean-280924 dataframe
path_df_prods_clean = r'/Users/janekobtseva/19-09-2024 Instacart Basket Analysis/02 Data/Prepared Data/df_prods_clean-280924.csv'

# %%
df_prods_clean = pd.read_csv(os.path.join(path_df_prods_clean), index_col = False)

# %%
df_prods_clean.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#merge 
df_ords_prods_merge = df_prods_clean.merge(df_orders_products_combined, on = 'product_id', indicator = False)

# %%
df_ords_prods_merge
# Out:
#           Unnamed: 0  product_id                product_name  aisle_id  \
# 0                  0           1  Chocolate Sandwich Cookies        61
# 1                  0           1  Chocolate Sandwich Cookies        61
# 2                  0           1  Chocolate Sandwich Cookies        61
# 3                  0           1  Chocolate Sandwich Cookies        61
# 4                  0           1  Chocolate Sandwich Cookies        61
# ...              ...         ...                         ...       ...
# 32406036       49692       49688      Fresh Foaming Cleanser        73
# 32406037       49692       49688      Fresh Foaming Cleanser        73
# 32406038       49692       49688      Fresh Foaming Cleanser        73
# 32406039       49692       49688      Fresh Foaming Cleanser        73
# 32406040       49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  user_id eval_set  order_number  \
# ...

# %%
#Export the merged file in pickle format as ords_prods_merge_new_variable.pkl

path_prepared_data = r'/Users/janekobtseva/19-09-2024 Instacart Basket Analysis/02 Data/Prepared Data'

# %%
df_ords_prods_merge.to_pickle(os.path.join(path_prepared_data, 'ords_prods_merge.pkl'))
